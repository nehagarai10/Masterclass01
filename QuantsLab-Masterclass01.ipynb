# %% [markdown]
# ##Statistics overview and Application in Finance
# ##Central Tendency and it's measures
# ##Log Returns and it's usefulness

# %% [markdown]
# Methods to construct a portfolio by checking various measures to check correlation between stocks, variance, standard deviation etc.

# %% [markdown]
# Correlation in the stocks, Why it's important to check the correlation between stocks before investing
# Methods to check correlation between stocks

# %% [markdown]
# Negative correction of the portfolio: A ideal portfolio should be negatively correlated to each so that it should be hedged when market falls

# %% [markdown]
# 1.Quite simply, using correlation information is a way to help you diversify and de-risk your portfolio. A highly correlated portfolio is a riskier portfolio. It means that when one of your stocks falls, it’s likely that all of them will fall by a similar amount.
#
# 2.Correlation is a statistical measure that determines how assets move in relation to each other. It can be used for individual securities, like stocks, or it can be used for entire markets. Correlation can be helpful in determining if there is a pattern or relationship between two sets of data. It can be useful when looking at stocks as those that are highly correlated may move together in the same direction (note: this doesn’t mean their returns will be the same). Quite simply, using correlation information is a way to help you diversify and de-risk your portfolio. A highly correlated portfolio is a riskier portfolio.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# %% [markdown]
# Let's download the data from yahoo finance free data resource

# %% [markdown]
# ### Central Tendency

# %%
### Mean
### Median 
### Mode

# %%
# Standard Deviation

list_pf_prices = [110,112,115,111,109,105]
np.std(list_pf_prices)
# Out:
# 3.0368111930480994

# %% [markdown]
# Skewness is a measure of the asymmetry of a distribution. A distribution is asymmetrical when its left and right side are not mirror images.
#
# A distribution can have right (or positive), left (or negative), or zero skewness. A right-skewed distribution is longer on the right side of its peak, and a left-skewed distribution is longer on the left side of its peak:

# %%
# Skewness

x1 = np.linspace( -5, 5, 1000 )
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2 )

plt.plot(x1, y1, '*')

print( '\nSkewness for data : ', skew(y1))
# Out:
# Skewness for data :  1.1108237139164436

# %% [markdown]
# In probability theory and statistics, kurtosis is a measure of the "tailedness" of the probability distribution of a real-valued random variable. Like skewness, kurtosis describes a particular aspect of a probability distribution. There are different ways to quantify kurtosis for a theoretical distribution, and there are corresponding ways of estimating it using a sample from a population. Different measures of kurtosis may have different interpretations.

# %%
# Kurtosis

x1 = np.linspace( -5, 5, 1000 )
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2 )
#p.plot(x1, y1, '*')
print( '\nKurtosis for normal distribution :', kurtosis(y1))
# Out:
# Kurtosis for normal distribution : -0.3073930877422071

# %% [markdown]
# ### Log Returns

# %%
# Price of Stock A at time T0

P0 = 100

# Price of Stock A at time T1

P1 = 50

# Price of Stock A at time T2

P2 = 100

# %%
change_1 = (P1 - P0)*100/P0
print(change_1, '%')
# Out:
# -50.0 %

# %%
change_2 = (P2 - P1)*100/P1
print(change_2, '%')
# Out:
# 100.0 %

# %%
total_change = (P2 - P0)*100/P0
print(total_change, '%')
# Out:
# 0.0 %

# %%
(change_1 + change_2)
# Out:
# 50.0

# %%
plt.plot([P0,P1,P2])

# %%
log_ret_1 = np.log(P1/P0)
log_ret_2 = np.log(P2/P1)

total_ret = np.log(P2/ P0)

# %%
log_ret_1, log_ret_2
# Out:
# (-0.6931471805599453, 0.6931471805599453)

# %%
log_ret_1 + log_ret_2
# Out:
# 0.0

# %%
total_ret
# Out:
# 0.0

# %%
stocks = ['RELIANCE.NS', 'INFY.NS', 'TCS.NS', 'ASIANPAINT.NS', 'ITC.NS']

# %%
stock_data = yf.download(stocks, start="2022-01-07", end="2023-01-07")
# Out:
# [*********************100%***********************]  5 of 5 completed

# %% [markdown]
# Data downloaded in Dataframe format

# %%
stock_data.head(5)
# Out:
#                Adj Close
#            ASIANPAINT.NS      INFY.NS      ITC.NS  RELIANCE.NS       TCS.NS
# Date
# 2022-01-07   3527.196045  1729.064941  204.079193  2428.687988  3698.132812  \
# 2022-01-10   3504.709229  1763.802490  208.657913  2430.681885  3723.420410
# 2022-01-11   3490.161621  1768.424683  207.396423  2448.179199  3758.016602
# 2022-01-12   3495.142578  1789.248169  208.143967  2513.532471  3704.274414
# 2022-01-13   3408.794434  1807.689087  209.265274  2527.689941  3740.742676
#
#                    Close
#            ASIANPAINT.NS      INFY.NS      ITC.NS  RELIANCE.NS       TCS.NS
# Date
# 2022-01-07   3576.300049  1814.300049  218.399994  2436.000000  3853.500000  \
# 2022-01-10   3553.500000  1850.750000  223.300003  2438.000000  3879.850098
# 2022-01-11   3538.750000  1855.599976  221.949997  2455.550049  3915.899902
# 2022-01-12   3543.800049  1877.449951  222.750000  2521.100098  3859.899902
# ...

# %% [markdown]
# Visualizing Stock Prices Changes and Returns

# %%
stock_data['Adj Close'].plot(secondary_y='RELI', figsize=(14,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Regression analysis on the stock data relies on the percentage returns instead of the absolute closing prices. Let's check and compare the logarithmic returns between the stocks

# %% [markdown]
# calculate the log returns for reliance and infosys using the numpy log method and assign the results

# %%
returns = np.log(stock_data['Adj Close']/ stock_data['Adj Close'].shift(1))
returns.dropna(inplace=True)
returns.plot(subplots=True, figsize=(14,6))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# observation: volatility pattern of the stock is high degree

# %% [markdown]
# Using scatter_matrix method to visualize the volatility pattern

# %%
pd.plotting.scatter_matrix(returns, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(14,6))
# Out:
# array([[<Axes: xlabel='ASIANPAINT.NS', ylabel='ASIANPAINT.NS'>,
#         <Axes: xlabel='INFY.NS', ylabel='ASIANPAINT.NS'>,
#         <Axes: xlabel='ITC.NS', ylabel='ASIANPAINT.NS'>,
#         <Axes: xlabel='RELIANCE.NS', ylabel='ASIANPAINT.NS'>,
#         <Axes: xlabel='TCS.NS', ylabel='ASIANPAINT.NS'>],
#        [<Axes: xlabel='ASIANPAINT.NS', ylabel='INFY.NS'>,
#         <Axes: xlabel='INFY.NS', ylabel='INFY.NS'>,
#         <Axes: xlabel='ITC.NS', ylabel='INFY.NS'>,
#         <Axes: xlabel='RELIANCE.NS', ylabel='INFY.NS'>,
#         <Axes: xlabel='TCS.NS', ylabel='INFY.NS'>],
#        [<Axes: xlabel='ASIANPAINT.NS', ylabel='ITC.NS'>,
#         <Axes: xlabel='INFY.NS', ylabel='ITC.NS'>,
#         <Axes: xlabel='ITC.NS', ylabel='ITC.NS'>,
#         <Axes: xlabel='RELIANCE.NS', ylabel='ITC.NS'>,
#         <Axes: xlabel='TCS.NS', ylabel='ITC.NS'>],
#        [<Axes: xlabel='ASIANPAINT.NS', ylabel='RELIANCE.NS'>,
#         <Axes: xlabel='INFY.NS', ylabel='RELIANCE.NS'>,
# ...

# %%
sns.heatmap(returns.corr())
# Out:
# <Axes: >

# %% [markdown]
# Let's calculate the correlation with method "Corr"

# %%
returns.corr()
# Out:
#                ASIANPAINT.NS   INFY.NS    ITC.NS  RELIANCE.NS    TCS.NS
# ASIANPAINT.NS       1.000000  0.345622  0.183223     0.243671  0.390602
# INFY.NS             0.345622  1.000000  0.275769     0.328535  0.760804
# ITC.NS              0.183223  0.275769  1.000000     0.323342  0.235260
# RELIANCE.NS         0.243671  0.328535  0.323342     1.000000  0.345513
# TCS.NS              0.390602  0.760804  0.235260     0.345513  1.000000

# %% [markdown]
# The least correlated stock is Itc

# %%
returns
# Out:
#             ASIANPAINT.NS   INFY.NS    ITC.NS  RELIANCE.NS    TCS.NS
# Date
# 2022-01-10      -0.006396  0.019891  0.022188     0.000821  0.006815
# 2022-01-11      -0.004160  0.002617 -0.006064     0.007173  0.009249
# 2022-01-12       0.001426  0.011706  0.003598     0.026345 -0.014404
# 2022-01-13      -0.025015  0.010254  0.005373     0.005617  0.009797
# 2022-01-14      -0.026935  0.017015 -0.006046     0.001458  0.017862
# ...                   ...       ...       ...          ...       ...
# 2023-01-02      -0.013252  0.010422  0.003913     0.011204  0.001458
# 2023-01-03      -0.006255 -0.000952 -0.005271    -0.007345  0.015184
# 2023-01-04      -0.003772 -0.018394 -0.012460    -0.015171  0.000996
# 2023-01-05      -0.004152 -0.013199  0.019533    -0.001788 -0.001072
# 2023-01-06      -0.008675 -0.018265  0.004787     0.009048 -0.030527
#
# [248 rows x 5 columns]

# %%
returns.mean()
# Out:
# ASIANPAINT.NS   -0.000709
# INFY.NS         -0.000822
# ITC.NS           0.001911
# RELIANCE.NS      0.000176
# TCS.NS          -0.000680
# dtype: float64

# %%
returns.std()
# Out:
# ASIANPAINT.NS    0.016922
# INFY.NS          0.017486
# ITC.NS           0.013148
# RELIANCE.NS      0.016668
# TCS.NS           0.014717
# dtype: float64

# %%
returns.var()
# Out:
# ASIANPAINT.NS    0.000286
# INFY.NS          0.000306
# ITC.NS           0.000173
# RELIANCE.NS      0.000278
# TCS.NS           0.000217
# dtype: float64

# %% [markdown]
# Central Tendency and it's measures
